# %%
import numpy as np
a = np.load('knn_score.npy')

# %%
a.shape
# Out:
# (12, 180, 360)

# %%
c = a[7,:,:]

# %%
c[0:32, 299:346] = np.nan
c[0:18,287:300] = np.nan

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.imshow(c)
plt.colorbar()

# %%
import numpy as np
koppen = np.genfromtxt("koppen_1901-2010.tsv", dtype=None, names=True)
print("The Koppen type at {} latitude and {} longitude is {}".format(
        koppen['latitude'][2], koppen['longitude'][2], koppen['p1901_2010'][2]))
# Out:
# The Koppen type at 68.25 latitude and -179.75 longitude is b'ET'

# %%
koppen
# Out:
# array([(-179.75,  71.25, b'ET'), (-179.75,  68.75, b'ET'),
#        (-179.75,  68.25, b'ET'), ..., ( 179.75, -88.75, b'EF'),
#        ( 179.75, -89.25, b'EF'), ( 179.75, -89.75, b'EF')],
#       dtype=[('longitude', '<f8'), ('latitude', '<f8'), ('p1901_2010', 'S3')])

# %%
import numpy as np

from libtiff import TIFF
tif = TIFF.open('Beck_KG_V1_future_0p5.tif', mode='r')
img = tif.read_image()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-161-ee398804fe20> in <module>()
#       1 import numpy as np
#       2
# ----> 3 from libtiff import TIFF
#       4 tif = TIFF.open('Beck_KG_V1_future_0p5.tif', mode='r')
#       5 img = tif.read_image()
#
# ModuleNotFoundError: No module named 'libtiff'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-162-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
koppen = np.genfromtxt("koppen_1901-2010.tsv", dtype=None, names=True)

# %%
koppen
# Out:
# array([(-179.75,  71.25, b'ET'), (-179.75,  68.75, b'ET'),
#        (-179.75,  68.25, b'ET'), ..., ( 179.75, -88.75, b'EF'),
#        ( 179.75, -89.25, b'EF'), ( 179.75, -89.75, b'EF')],
#       dtype=[('longitude', '<f8'), ('latitude', '<f8'), ('p1901_2010', 'S3')])

# %%
from PIL import Image

# %%
im = Image.open('Beck_KG_V1_future_0p5.tif')

# %%
a =np.array(im)

# %%
a.shape
# Out:
# ()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\DELL\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
a =plt.imread('Beck_KG_V1_future_0p5.tif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in pil_to_array(pilImage)
#    1455         try:
# -> 1456             pilImage = pilImage.convert('RGBA')
#    1457         except ValueError:
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#     891
# --> 892         self.load()
#     893
#
# ~\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py in load(self)
#    1061             return self._load_libtiff()
# -> 1062         return super(TiffImageFile, self).load()
#    1063
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     210                     seek(offset)
# --> 211                     decoder.setimage(self.im, extents)
#     212                     if decoder.pulls_fd:
#
# ValueError: tile cannot extend outside image
#
# ...

# %%
import h5py
koppen_index = np.array(h5py.File('koppen_index.mat')['koppen_index']).T
koppen_index = np.concatenate((koppen_index[:,361:], koppen_index[:,:361]), axis=-1)

# %%
np.save('koppen_index_05.npy', koppen_index)

# %%
koppen_index = np.load('koppen_index_05.npy')

# %%
koppen_index = koppen_index[::2,::2]

# %%
plt.imshow(koppen_index)

# %%
koppen_index.shape
# Out:
# (180, 360)

# %%
np.save('koppen_index.npy', koppen_index)
